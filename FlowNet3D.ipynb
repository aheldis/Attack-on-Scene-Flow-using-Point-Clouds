# %%
# !git clone https://github.com/aheldis/FlowNet3D.git
# Out:
# Cloning into 'FlowNet3D'...
# remote: Enumerating objects: 149, done.
# remote: Counting objects: 100% (149/149), done.
# remote: Compressing objects: 100% (94/94), done.
# remote: Total 149 (delta 91), reused 98 (delta 54), pack-reused 0
# Receiving objects: 100% (149/149), 4.04 MiB | 17.16 MiB/s, done.
# Resolving deltas: 100% (91/91), done.

# %%
cd FlowNet3D/
# Out:
# /content/FlowNet3D

# %%
cd lib
# Out:
# /content/FlowNet3D/lib

# %%
# !python setup.py install
# Out:
# running install
# /usr/lib/python3.10/distutils/cmd.py:62: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/lib/python3.10/distutils/cmd.py:62: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
# ...

# %%
cd ..
# Out:
# /content/FlowNet3D

# %%
# !mkdir data

# %%
cd data
# Out:
# /content/FlowNet3D/data

# %%
# !gdown 1CMaxdt-Tg1Wct8v8eGNwuT7qRSIyJPY-
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1CMaxdt-Tg1Wct8v8eGNwuT7qRSIyJPY-
# To: /content/data_processed_maxcut_35_20k_2k_8192.tar
# 100% 11.0G/11.0G [01:11<00:00, 155MB/s]

# %%
# !tar -xvf data_processed_maxcut_35_20k_2k_8192.tar
# Out:
# Streaming output truncated to the last 5000 lines.
# data_processed_maxcut_35_20k_2k_8192/TEST_C_0089_left_0014-0.npz
# data_processed_maxcut_35_20k_2k_8192/TRAIN_A_0716_left_0010-0.npz
# data_processed_maxcut_35_20k_2k_8192/TRAIN_B_0178_right_0012-0.npz
# data_processed_maxcut_35_20k_2k_8192/TRAIN_C_0431_right_0009-0.npz
# data_processed_maxcut_35_20k_2k_8192/TRAIN_C_0684_right_0009-0.npz
# data_processed_maxcut_35_20k_2k_8192/TRAIN_B_0632_left_0010-0.npz
# data_processed_maxcut_35_20k_2k_8192/TRAIN_B_0177_left_0007-0.npz
# data_processed_maxcut_35_20k_2k_8192/TRAIN_B_0475_right_0012-0.npz
# data_processed_maxcut_35_20k_2k_8192/TRAIN_C_0571_right_0009-0.npz
# data_processed_maxcut_35_20k_2k_8192/TRAIN_C_0641_left_0007-0.npz
# data_processed_maxcut_35_20k_2k_8192/TRAIN_B_0528_right_0012-0.npz
# data_processed_maxcut_35_20k_2k_8192/TRAIN_C_0305_left_0013-0.npz
# data_processed_maxcut_35_20k_2k_8192/TRAIN_B_0411_right_0010-0.npz
# ...

# %%
# !gdown 1XBsF35wKY0rmaL7x7grD_evvKCAccbKi
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1XBsF35wKY0rmaL7x7grD_evvKCAccbKi
# To: /content/FlowNet3D/data/kitti_rm_ground.tar
# 100% 279M/279M [00:01<00:00, 147MB/s]

# %%
# !tar -xvf kitti_rm_ground.tar
# Out:
# kitti_rm_ground/
# kitti_rm_ground/000054.npz
# kitti_rm_ground/000080.npz
# kitti_rm_ground/000091.npz
# kitti_rm_ground/000147.npz
# kitti_rm_ground/000024.npz
# kitti_rm_ground/000104.npz
# kitti_rm_ground/000035.npz
# kitti_rm_ground/000144.npz
# kitti_rm_ground/000119.npz
# kitti_rm_ground/000026.npz
# kitti_rm_ground/000051.npz
# kitti_rm_ground/000131.npz
# kitti_rm_ground/000052.npz
# kitti_rm_ground/000095.npz
# kitti_rm_ground/000060.npz
# kitti_rm_ground/000084.npz
# kitti_rm_ground/000077.npz
# kitti_rm_ground/000089.npz
# kitti_rm_ground/000048.npz
# kitti_rm_ground/000097.npz
# kitti_rm_ground/000120.npz
# kitti_rm_ground/000082.npz
# kitti_rm_ground/000129.npz
# kitti_rm_ground/000002.npz
# kitti_rm_ground/000088.npz
# kitti_rm_ground/000010.npz
# kitti_rm_ground/000116.npz
# kitti_rm_ground/000006.npz
# kitti_rm_ground/000014.npz
# kitti_rm_ground/000069.npz
# kitti_rm_ground/000071.npz
# kitti_rm_ground/000105.npz
# kitti_rm_ground/000058.npz
# ...

# %%
cd ..
# Out:
# /content/FlowNet3D

# %%
# !python flying_things_main.py --exp_name=flownet3d --dataset_path=data/data_processed_maxcut_35_20k_2k_8192 --model_path=pretrained_model/model.best.t7 --attack_type=None

# %%
# !python flying_things_main.py --exp_name=flownet3d --dataset_path=data/data_processed_maxcut_35_20k_2k_8192 --model_path=pretrained_model/model.best.t7 --attack_type=FGSM --channel=-1

# %%
# !python flying_things_main.py --exp_name=flownet3d --dataset_path=data/data_processed_maxcut_35_20k_2k_8192 --model_path=pretrained_model/model.best.t7 --attack_type=FGSM --channel=0

# %%
# !python flying_things_main.py --exp_name=flownet3d --dataset_path=data/data_processed_maxcut_35_20k_2k_8192 --model_path=pretrained_model/model.best.t7 --attack_type=FGSM --channel=1

# %%
# !python flying_things_main.py --exp_name=flownet3d --dataset_path=data/data_processed_maxcut_35_20k_2k_8192 --model_path=pretrained_model/model.best.t7 --attack_type=FGSM --channel=2

# %%
# !python flying_things_main.py --exp_name=flownet3d --dataset_path=data/data_processed_maxcut_35_20k_2k_8192 --model_path=pretrained_model/model.best.t7 --attack_type=PGD --channel=-1

# %%
# !python flying_things_main.py --exp_name=flownet3d --dataset_path=data/data_processed_maxcut_35_20k_2k_8192 --model_path=pretrained_model/model.best.t7 --attack_type=PGD --channel=0

# %%
# !python flying_things_main.py --exp_name=flownet3d --dataset_path=data/data_processed_maxcut_35_20k_2k_8192 --model_path=pretrained_model/model.best.t7 --attack_type=PGD --channel=1

# %%
# !python flying_things_main.py --exp_name=flownet3d --dataset_path=data/data_processed_maxcut_35_20k_2k_8192 --model_path=pretrained_model/model.best.t7 --attack_type=PGD --channel=2

# %%
# !python flying_things_main.py --exp_name=flownet3d --dataset_path=data/data_processed_maxcut_35_20k_2k_8192 --model_path=pretrained_model/model.best.t7 --attack_type=RAND --channel=-1

# %%
# !python kitti_main.py --exp_name=flownet3d --dataset_path=data/kitti_rm_ground --model_path=pretrained_model/model.best.t7 --attack_type=None
# Out:
# /content/FlowNet3D/kitti_main.py:304: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if args.model_path is '':
# cp: cannot stat 'main.py': No such file or directory
# cp: cannot stat 'model.py': No such file or directory
# cp: cannot stat 'data.py': No such file or directory
# Namespace(exp_name='flownet3d', model='flownet', emb_dims=512, num_points=2048, dropout=0.5, batch_size=64, test_batch_size=8, epochs=250, use_sgd=False, lr=0.001, momentum=0.9, no_cuda=False, seed=1234, eval=True, cycle=False, gaussian_noise=False, unseen=False, dataset='SceneflowDataset', dataset_path='data/kitti_rm_ground', model_path='pretrained_model/model.best.t7', attack_type='None', iters=10, epsilon=10, channel=-1)
# pretrained_model/model.best.t7
# 100% 19/19 [00:04<00:00,  3.91it/s]
# ==FINAL TEST==
# mean test loss: 0.071037	EPE 3D: 0.291906	ACC 3D: 0.035540	ACC 3D 2: 0.188617
# FINISH

# %%
# !python kitti_main.py --exp_name=flownet3d --dataset_path=data/kitti_rm_ground --model_path=pretrained_model/model.best.t7 --attack_type=FGSM --channel=-1
# Out:
# /content/FlowNet3D/kitti_main.py:304: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if args.model_path is '':
# cp: cannot stat 'main.py': No such file or directory
# cp: cannot stat 'model.py': No such file or directory
# cp: cannot stat 'data.py': No such file or directory
# Namespace(exp_name='flownet3d', model='flownet', emb_dims=512, num_points=2048, dropout=0.5, batch_size=64, test_batch_size=8, epochs=250, use_sgd=False, lr=0.001, momentum=0.9, no_cuda=False, seed=1234, eval=True, cycle=False, gaussian_noise=False, unseen=False, dataset='SceneflowDataset', dataset_path='data/kitti_rm_ground', model_path='pretrained_model/model.best.t7', attack_type='FGSM', iters=10, epsilon=10, channel=-1)
# pretrained_model/model.best.t7
# 100% 19/19 [00:07<00:00,  2.52it/s]
# ==FINAL TEST==
# mean test loss: 0.753515	EPE 3D: 1.115135	ACC 3D: 0.000036	ACC 3D 2: 0.000553
# FINISH

# %%
# !python kitti_main.py --exp_name=flownet3d --dataset_path=data/kitti_rm_ground --model_path=pretrained_model/model.best.t7 --attack_type=FGSM --channel=0
# Out:
# /content/FlowNet3D/kitti_main.py:304: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if args.model_path is '':
# cp: cannot stat 'main.py': No such file or directory
# cp: cannot stat 'model.py': No such file or directory
# cp: cannot stat 'data.py': No such file or directory
# Namespace(exp_name='flownet3d', model='flownet', emb_dims=512, num_points=2048, dropout=0.5, batch_size=64, test_batch_size=8, epochs=250, use_sgd=False, lr=0.001, momentum=0.9, no_cuda=False, seed=1234, eval=True, cycle=False, gaussian_noise=False, unseen=False, dataset='SceneflowDataset', dataset_path='data/kitti_rm_ground', model_path='pretrained_model/model.best.t7', attack_type='FGSM', iters=10, epsilon=10, channel=0)
# pretrained_model/model.best.t7
# 100% 19/19 [00:07<00:00,  2.55it/s]
# ==FINAL TEST==
# mean test loss: 0.495711	EPE 3D: 0.896095	ACC 3D: 0.000130	ACC 3D 2: 0.001341
# FINISH

# %%
# !python kitti_main.py --exp_name=flownet3d --dataset_path=data/kitti_rm_ground --model_path=pretrained_model/model.best.t7 --attack_type=FGSM --channel=1
# Out:
# /content/FlowNet3D/kitti_main.py:304: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if args.model_path is '':
# cp: cannot stat 'main.py': No such file or directory
# cp: cannot stat 'model.py': No such file or directory
# cp: cannot stat 'data.py': No such file or directory
# Namespace(exp_name='flownet3d', model='flownet', emb_dims=512, num_points=2048, dropout=0.5, batch_size=64, test_batch_size=8, epochs=250, use_sgd=False, lr=0.001, momentum=0.9, no_cuda=False, seed=1234, eval=True, cycle=False, gaussian_noise=False, unseen=False, dataset='SceneflowDataset', dataset_path='data/kitti_rm_ground', model_path='pretrained_model/model.best.t7', attack_type='FGSM', iters=10, epsilon=10, channel=1)
# pretrained_model/model.best.t7
# 100% 19/19 [00:07<00:00,  2.62it/s]
# ==FINAL TEST==
# mean test loss: 0.817987	EPE 3D: 1.179472	ACC 3D: 0.000016	ACC 3D 2: 0.000293
# FINISH

# %%
# !python kitti_main.py --exp_name=flownet3d --dataset_path=data/kitti_rm_ground --model_path=pretrained_model/model.best.t7 --attack_type=FGSM --channel=2
# Out:
# /content/FlowNet3D/kitti_main.py:304: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if args.model_path is '':
# cp: cannot stat 'main.py': No such file or directory
# cp: cannot stat 'model.py': No such file or directory
# cp: cannot stat 'data.py': No such file or directory
# Namespace(exp_name='flownet3d', model='flownet', emb_dims=512, num_points=2048, dropout=0.5, batch_size=64, test_batch_size=8, epochs=250, use_sgd=False, lr=0.001, momentum=0.9, no_cuda=False, seed=1234, eval=True, cycle=False, gaussian_noise=False, unseen=False, dataset='SceneflowDataset', dataset_path='data/kitti_rm_ground', model_path='pretrained_model/model.best.t7', attack_type='FGSM', iters=10, epsilon=10, channel=2)
# pretrained_model/model.best.t7
# 100% 19/19 [00:07<00:00,  2.60it/s]
# ==FINAL TEST==
# mean test loss: 0.797129	EPE 3D: 1.154301	ACC 3D: 0.000020	ACC 3D 2: 0.000475
# FINISH

# %%
# !python kitti_main.py --exp_name=flownet3d --dataset_path=data/kitti_rm_ground --model_path=pretrained_model/model.best.t7 --attack_type=PGD --channel=-1

# %%
# !python kitti_main.py --exp_name=flownet3d --dataset_path=data/kitti_rm_ground --model_path=pretrained_model/model.best.t7 --attack_type=PGD --channel=0

# %%
# !python kitti_main.py --exp_name=flownet3d --dataset_path=data/kitti_rm_ground --model_path=pretrained_model/model.best.t7 --attack_type=PGD --channel=1

# %%
# !python kitti_main.py --exp_name=flownet3d --dataset_path=data/kitti_rm_ground --model_path=pretrained_model/model.best.t7 --attack_type=PGD --channel=2

# %%
# !python kitti_main.py --exp_name=flownet3d --dataset_path=data/kitti_rm_ground --model_path=pretrained_model/model.best.t7 --attack_type=RAND --channel=-1
