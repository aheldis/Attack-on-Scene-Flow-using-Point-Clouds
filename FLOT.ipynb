# %%
# !git clone https://github.com/aheldis/FLOT.git
# Out:
# Cloning into 'FLOT'...
# remote: Enumerating objects: 128, done.
# remote: Counting objects: 100% (128/128), done.
# remote: Compressing objects: 100% (118/118), done.
# remote: Total 128 (delta 59), reused 35 (delta 6), pack-reused 0
# Receiving objects: 100% (128/128), 1.10 MiB | 20.85 MiB/s, done.
# Resolving deltas: 100% (59/59), done.

# %%
# !pip install -e ./FLOT
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/FLOT
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for flot
# ...

# %%
cd FLOT
# Out:
# /content/FLOT

# %%
cd flot
# Out:
# /content/FLOT/flot

# %%
# !mkdir data

# %%
# !pip install gdown
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
cd data
# Out:
# /content/FLOT/flot/data

# %%
# !mkdir flownet3d

# %%
cd flownet3d
# Out:
# /content/FLOT/flot/data/flownet3d

# %%
# !pip install gdown
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !gdown 1CMaxdt-Tg1Wct8v8eGNwuT7qRSIyJPY-
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1CMaxdt-Tg1Wct8v8eGNwuT7qRSIyJPY-
# To: /content/FLOT/flot/data/flownet3d/data_processed_maxcut_35_20k_2k_8192.tar
# 100% 11.0G/11.0G [01:25<00:00, 129MB/s]

# %%
# !tar -xvf data_processed_maxcut_35_20k_2k_8192.tar
# Out:
# Streaming output truncated to the last 5000 lines.
# data_processed_maxcut_35_20k_2k_8192/TEST_C_0089_left_0014-0.npz
# data_processed_maxcut_35_20k_2k_8192/TRAIN_A_0716_left_0010-0.npz
# data_processed_maxcut_35_20k_2k_8192/TRAIN_B_0178_right_0012-0.npz
# data_processed_maxcut_35_20k_2k_8192/TRAIN_C_0431_right_0009-0.npz
# data_processed_maxcut_35_20k_2k_8192/TRAIN_C_0684_right_0009-0.npz
# data_processed_maxcut_35_20k_2k_8192/TRAIN_B_0632_left_0010-0.npz
# data_processed_maxcut_35_20k_2k_8192/TRAIN_B_0177_left_0007-0.npz
# data_processed_maxcut_35_20k_2k_8192/TRAIN_B_0475_right_0012-0.npz
# data_processed_maxcut_35_20k_2k_8192/TRAIN_C_0571_right_0009-0.npz
# data_processed_maxcut_35_20k_2k_8192/TRAIN_C_0641_left_0007-0.npz
# data_processed_maxcut_35_20k_2k_8192/TRAIN_B_0528_right_0012-0.npz
# data_processed_maxcut_35_20k_2k_8192/TRAIN_C_0305_left_0013-0.npz
# data_processed_maxcut_35_20k_2k_8192/TRAIN_B_0411_right_0010-0.npz
# ...

# %%
# !gdown 1XBsF35wKY0rmaL7x7grD_evvKCAccbKi

# %%
# !tar -xvf kitti_rm_ground.tar

# %%
cd ..
# Out:
# /content/FLOT/flot/data

# %%
cd ..
# Out:
# /content/FLOT/flot

# %%
cd scripts
# Out:
# /content/FLOT/flot/scripts

# %%
! python val_test.py --dataset flownet3D_kitti --test --nb_points 2048 --path2ckpt ../pretrained_models/model_2048.tar --attack_type=None

# %%
! python val_test.py --dataset flownet3D_kitti --test --nb_points 2048 --path2ckpt ../pretrained_models/model_2048.tar --attack_type=FGSM --channel=-1

# %%
! python val_test.py --dataset flownet3D_kitti --test --nb_points 2048 --path2ckpt ../pretrained_models/model_2048.tar --attack_type=FGSM --channel=0

# %%
! python val_test.py --dataset flownet3D_kitti --test --nb_points 2048 --path2ckpt ../pretrained_models/model_2048.tar --attack_type=FGSM --channel=1

# %%
! python val_test.py --dataset flownet3D_kitti --test --nb_points 2048 --path2ckpt ../pretrained_models/model_2048.tar --attack_type=FGSM --channel=2

# %%
! python val_test.py --dataset flownet3D_kitti --test --nb_points 2048 --path2ckpt ../pretrained_models/model_2048.tar --attack_type=PGD --channel=-1

# %%
! python val_test.py --dataset flownet3D_kitti --test --nb_points 2048 --path2ckpt ../pretrained_models/model_2048.tar --attack_type=PGD --channel=0

# %%
! python val_test.py --dataset flownet3D_kitti --test --nb_points 2048 --path2ckpt ../pretrained_models/model_2048.tar --attack_type=PGD --channel=1

# %%
! python val_test.py --dataset flownet3D_kitti --test --nb_points 2048 --path2ckpt ../pretrained_models/model_2048.tar --attack_type=PGD --channel=2

# %%
! python val_test.py --dataset flownet3D_kitti --test --nb_points 2048 --path2ckpt ../pretrained_models/model_2048.tar  --attack_type=RAND --channel=-1

# %%
! python val_test.py --dataset flownet3D_ft3d --test --nb_points 2048 --path2ckpt ../pretrained_models/model_2048.tar --attack_type=None

# %%
! python val_test.py --dataset flownet3D_ft3d --test --nb_points 2048 --path2ckpt ../pretrained_models/model_2048.tar --attack_type=FGSM --channel=-1

# %%
! python val_test.py --dataset flownet3D_ft3d --test --nb_points 2048 --path2ckpt ../pretrained_models/model_2048.tar --attack_type=FGSM --channel=0

# %%
! python val_test.py --dataset flownet3D_ft3d --test --nb_points 2048 --path2ckpt ../pretrained_models/model_2048.tar --attack_type=FGSM --channel=1

# %%
! python val_test.py --dataset flownet3D_ft3d --test --nb_points 2048 --path2ckpt ../pretrained_models/model_2048.tar --attack_type=FGSM --channel=2

# %%
! python val_test.py --dataset flownet3D_ft3d --test --nb_points 2048 --path2ckpt ../pretrained_models/model_2048.tar --attack_type=PGD --channel=-1

# %%
! python val_test.py --dataset flownet3D_ft3d --test --nb_points 2048 --path2ckpt ../pretrained_models/model_2048.tar --attack_type=PGD --channel=0

# %%
! python val_test.py --dataset flownet3D_ft3d --test --nb_points 2048 --path2ckpt ../pretrained_models/model_2048.tar --attack_type=PGD --channel=1

# %%
! python val_test.py --dataset flownet3D_ft3d --test --nb_points 2048 --path2ckpt ../pretrained_models/model_2048.tar --attack_type=PGD --channel=2

# %%
! python val_test.py --dataset flownet3D_ft3d --test --nb_points 2048 --path2ckpt ../pretrained_models/model_2048.tar  --attack_type=RAND --channel=-1
